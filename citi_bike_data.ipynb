# %%
import pandas as pd
import datetime as dt

# %%
citiBike_data01 = pd.read_csv("Data/202101-citibike-tripdata.csv")
citiBike_data02 = pd.read_csv("Data/202102-citibike-tripdata.csv")
citiBike_data03 = pd.read_csv("Data/202103-citibike-tripdata.csv")
citiBike_data04 = pd.read_csv("Data/202104-citibike-tripdata.csv")

citiBike_data01 = pd.DataFrame(citiBike_data01)
citiBike_data02 = pd.DataFrame(citiBike_data02)
citiBike_data03 = pd.DataFrame(citiBike_data03)
citiBike_data04 = pd.DataFrame(citiBike_data04)

# %%
# Concatenate csv files into one file
citiBike_data = pd.concat([citiBike_data01, citiBike_data02, citiBike_data03, citiBike_data04])

citiBike_data
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                2513  2021-01-01 00:00:11.9020  2021-01-01 00:42:05.2260
# 1                2519  2021-01-01 00:00:15.0960  2021-01-01 00:42:14.9780
# 2                1207  2021-01-01 00:00:28.9300  2021-01-01 00:20:36.6510
# 3                2506  2021-01-01 00:00:32.7130  2021-01-01 00:42:19.3980
# 4                 959  2021-01-01 00:00:35.3650  2021-01-01 00:16:34.6010
# ...               ...                       ...                       ...
# 2016146           711  2021-04-30 23:59:55.2130  2021-05-01 00:11:46.4140
# 2016147           687  2021-04-30 23:59:55.6720  2021-05-01 00:11:22.8090
# 2016148          1511  2021-04-30 23:59:56.2250  2021-05-01 00:25:07.7140
# 2016149           781  2021-04-30 23:59:56.3250  2021-05-01 00:12:58.1230
# 2016150          1295  2021-04-30 23:59:57.0600  2021-05-01 00:21:32.6890
#
#          start station id              start station name  \
# ...

# %%
# Convert duration column from seconds to minutes
citiBike_data['tripduration'] = citiBike_data['tripduration'].astype('float') 
citiBike_data['tripduration'] = (citiBike_data['tripduration'] / 60).round(2)
# Dropping outlier data
citiBike_data = citiBike_data[citiBike_data['tripduration'] < 100]

citiBike_data
# Out:
#          tripduration                 starttime                  stoptime  \
# 0               41.88  2021-01-01 00:00:11.9020  2021-01-01 00:42:05.2260
# 1               41.98  2021-01-01 00:00:15.0960  2021-01-01 00:42:14.9780
# 2               20.12  2021-01-01 00:00:28.9300  2021-01-01 00:20:36.6510
# 3               41.77  2021-01-01 00:00:32.7130  2021-01-01 00:42:19.3980
# 4               15.98  2021-01-01 00:00:35.3650  2021-01-01 00:16:34.6010
# ...               ...                       ...                       ...
# 2016146         11.85  2021-04-30 23:59:55.2130  2021-05-01 00:11:46.4140
# 2016147         11.45  2021-04-30 23:59:55.6720  2021-05-01 00:11:22.8090
# 2016148         25.18  2021-04-30 23:59:56.2250  2021-05-01 00:25:07.7140
# 2016149         13.02  2021-04-30 23:59:56.3250  2021-05-01 00:12:58.1230
# 2016150         21.58  2021-04-30 23:59:57.0600  2021-05-01 00:21:32.6890
#
#          start station id              start station name  \
# ...

# %%
# Convert gender column to words
citiBike_data['gender'] = citiBike_data['gender'].astype('str') 
citiBike_data['gender'].replace({"1": "male", "2": "female", "0": "unknown"}, inplace=True)

citiBike_data
# Out:
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#          tripduration                 starttime                  stoptime  \
# 0               41.88  2021-01-01 00:00:11.9020  2021-01-01 00:42:05.2260
# 1               41.98  2021-01-01 00:00:15.0960  2021-01-01 00:42:14.9780
# ...

# %%
# Rename Columns
citiBike_data = citiBike_data.rename(columns={'tripduration': 'Trip Duration (Minutes)',
                                              'starttime': 'Start Time',
                                              'stoptime': 'Stop Time',
                                              'start station id': 'Start Station ID',
                                              'start station name': 'Start Station Name',
                                              'start station latitude': 'Start Station Latitude',
                                              'start station longitude': 'Start Station Longitude', 
                                              'end station id': 'End Station ID',
                                              'end station name': 'End Station Name',
                                              'end station latitude': 'End Station Latitude',
                                              'end station longitude': 'End Station Longitude',
                                              'bikeid': 'Bike ID',
                                              'usertype': 'User Type',
                                              'birth year': 'Birth Year',
                                              'gender': 'Gender'})
citiBike_data
# Out:
#          Trip Duration (Minutes)                Start Time  \
# 0                          41.88  2021-01-01 00:00:11.9020
# 1                          41.98  2021-01-01 00:00:15.0960
# 2                          20.12  2021-01-01 00:00:28.9300
# 3                          41.77  2021-01-01 00:00:32.7130
# 4                          15.98  2021-01-01 00:00:35.3650
# ...                          ...                       ...
# 2016146                    11.85  2021-04-30 23:59:55.2130
# 2016147                    11.45  2021-04-30 23:59:55.6720
# 2016148                    25.18  2021-04-30 23:59:56.2250
# 2016149                    13.02  2021-04-30 23:59:56.3250
# 2016150                    21.58  2021-04-30 23:59:57.0600
#
#                         Stop Time  Start Station ID  \
# 0        2021-01-01 00:42:05.2260              3581
# 1        2021-01-01 00:42:14.9780              3581
# 2        2021-01-01 00:20:36.6510              3144
# ...

# %%
# Export file
citiBike_data.to_csv("Data/citiData.csv")
